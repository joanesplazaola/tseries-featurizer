# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
# %matplotlib inline
raw_files = glob('/media/joanes/0BB3-1FA1/CSV_DATA/*.csv')

# %%
def get_df_list_and_target(files):
	# Get only those values that are available before the analysis
	filter_cols = ['Total_UnfilledZones', 'Total_FillingQuality', 'TOTAL_QUALITY', 'Total_PorosityQuantity',
				   'Total_PorosityQuality', 'Time']
	df_list = list()
	target = list()
	for file in files:
		df = pd.read_csv(file)
		target.append(df.TOTAL_QUALITY.unique()[0])
		df_filtered = df.drop(axis=1, columns=filter_cols)
		filter_col = [col for col in df_filtered if
					  not col.endswith(('VoidContent', 'VoidQuality', 'Filling', 'FillingQuality'))]
		df_filtered = df_filtered[filter_col]
		df_list.append(df_filtered)

	target = pd.DataFrame(target, columns=['valid'])
	return df_list, target

# %%
def split_df(df, indexes, starting_index=0):
    df_list = []
    for index, i in enumerate(indexes[:len(indexes)]):
        df_slice = df[starting_index:i].reset_index()
        df_slice.rename(columns=lambda x: f'slice_{index}_{x}', inplace=True)
        df_list.append(df_slice)
        starting_index = i
    df_slice = df[indexes[-1]:].reset_index()
    df_slice.rename(columns=lambda x: f'slice_{index + 1}_{x}', inplace=True)
    df_list.append(df_slice)
    return df_list

# %%
import peakutils
from scipy.signal import savgol_filter


def get_processed_df_list_and_target(raw_files, start, end):
    nidea_list = []
    df_list, targets = get_df_list_and_target(raw_files[start:end])
    print(len(raw_files[start:end]))
    for data in df_list:
        flow_rate_filtered = savgol_filter(data['Flow rate'].values, 51, 2)
        flow_rate_deriv = np.diff(flow_rate_filtered) * -1
        flow_rate = flow_rate_deriv[350:500]
        np.place(flow_rate, flow_rate < 0, [0])
        indexes = peakutils.indexes(flow_rate, thres=0.08, min_dist=10) + 350
        flow_rate = flow_rate_deriv[580:]
        np.place(flow_rate, flow_rate < 0, [0])
        indexes2 = peakutils.indexes(flow_rate, thres=0.2, min_dist=10) + 580

        df_list = split_df(data, [indexes[0], indexes2[0]])

        nidea_list.append(pd.concat(df_list, axis=1))
    return nidea_list, targets

# %%
# Add library's path to notebook
import os
import sys

sys.path.append('../../time-series-featurizer/')

print('Tseries loaded')
from ts_featurizer import TimeSeriesFeaturizer

tseries = TimeSeriesFeaturizer(check_na=False)
model = tseries.featurize(nidea_list[:200], n_jobs=-1)
# Out:
# Tseries loaded
#
#
# -------------------------------------------------- Modeling started --------------------------------------------------
#   0%|          | 0/82 [00:00<?, ?it/s]/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: divide by zero encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: divide by zero encountered in true_divide
#  17%|█▋        | 14/82 [15:20<12:03:44, 638.60s/it]/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#  22%|██▏       | 18/82 [29:12<7:03:27, 397.00s/it] /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#  43%|████▎     | 35/82 [42:15<1:57:22, 149.83s/it]/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
#  54%|█████▎    | 44/82 [42:59<49:49, 78.67s/it]   /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: divide by zero encountered in true_divide
# 100%|██████████| 82/82 [1:49:21<00:00, 80.02s/it]
# ../../time-series-featurizer/ts_featurizer/base/base.py:155: UserWarning: NaN values have been found while Modeling, check na_cols attribute to know which columns have NaNs.

# %%
import pickle

filehandler = open('tmp/tseries_folded.pickle', 'wb')
pickle.dump(tseries, filehandler)

# %%
with open('tmp/tseries_folded.pickle', 'rb') as filehandler:
	tseries = pickle.load(filehandler)

# %%
for time in range(4, 10):
    print(time)
    df_list, target_featurized = get_processed_df_list_and_target(raw_files, (time - 1) * 1_000, time * 1_000)
    print(f'Loaded DataFrame lists len is {len(df_list)}, from {(time - 1) * 1_000} to {time * 1_000}')
    featurized = tseries.featurize(df_list, n_jobs=-1, apply_model=True)
    featurized.reset_index(drop=True).to_feather(f'tmp/featurized_{time}')
    target_featurized.reset_index(drop=True).to_feather(f'tmp/target_featurized_{time}')
    print('Stored the featurized files')
# Out:
# 4
# 1000
# Loaded DataFrame lists len is 1000, from 3000 to 4000
#
#
# -------------------------------------------------- Applying the model started --------------------------------------------------
#   0%|          | 0/82 [00:00<?, ?it/s]/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: divide by zero encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: divide by zero encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#   1%|          | 1/82 [1:23:24<112:35:29, 5004.07s/it]/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#  21%|██        | 17/82 [2:27:54<64:33:22, 3575.42s/it]/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#  28%|██▊       | 23/82 [2:34:46<20:41:06, 1262.14s/it]/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#  57%|█████▋    | 47/82 [3:42:25<51:26, 88.19s/it]     /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: divide by zero encountered in true_divide
# 100%|██████████| 82/82 [8:27:43<00:00, 371.51s/it]
# ../../time-series-featurizer/ts_featurizer/base/base.py:155: UserWarning: NaN values have been found while Applying the model, check na_cols attribute to know which columns have NaNs.
# Stored the featurized files
# 5
# 1000
# /home/joanes/miniconda3/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# Loaded DataFrame lists len is 1000, from 4000 to 5000
#
#
# -------------------------------------------------- Applying the model started --------------------------------------------------
#   0%|          | 0/82 [00:00<?, ?it/s]/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: divide by zero encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#   1%|          | 1/82 [1:18:44<106:18:12, 4724.60s/it]/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: divide by zero encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#  26%|██▌       | 21/82 [2:31:18<14:22:36, 848.46s/it] /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#  28%|██▊       | 23/82 [2:32:49<9:57:31, 607.65s/it] /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#  41%|████▏     | 34/82 [3:40:49<5:35:22, 419.21s/it]/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
#  59%|█████▊    | 48/82 [3:45:37<1:10:19, 124.11s/it]/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: divide by zero encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# 100%|██████████| 82/82 [8:36:27<00:00, 377.89s/it]
# ../../time-series-featurizer/ts_featurizer/base/base.py:155: UserWarning: NaN values have been found while Applying the model, check na_cols attribute to know which columns have NaNs.
# Stored the featurized files
# 6
# 1000
# /home/joanes/miniconda3/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# Loaded DataFrame lists len is 1000, from 5000 to 6000
#
#
# -------------------------------------------------- Applying the model started --------------------------------------------------
#   0%|          | 0/82 [00:00<?, ?it/s]/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: divide by zero encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: divide by zero encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#   2%|▏         | 2/82 [1:27:40<81:49:45, 3682.31s/it] /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#  27%|██▋       | 22/82 [2:30:58<22:31:11, 1351.19s/it]/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#  28%|██▊       | 23/82 [2:32:57<16:05:10, 981.53s/it] /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#  39%|███▉      | 32/82 [2:43:04<9:49:25, 707.31s/it] /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#  57%|█████▋    | 47/82 [3:44:17<1:56:09, 199.14s/it]  /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: divide by zero encountered in true_divide
#  59%|█████▊    | 48/82 [3:55:12<3:10:15, 335.75s/it]/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# 100%|██████████| 82/82 [8:37:12<00:00, 378.45s/it]
# ../../time-series-featurizer/ts_featurizer/base/base.py:155: UserWarning: NaN values have been found while Applying the model, check na_cols attribute to know which columns have NaNs.
# Stored the featurized files
# 7
# 1000
# /home/joanes/miniconda3/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# Loaded DataFrame lists len is 1000, from 6000 to 7000
#
#
# -------------------------------------------------- Applying the model started --------------------------------------------------
#   0%|          | 0/82 [00:00<?, ?it/s]/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: divide by zero encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#   1%|          | 1/82 [1:16:37<103:26:33, 4597.45s/it]/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: divide by zero encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#  23%|██▎       | 19/82 [2:27:39<28:30:49, 1629.36s/it]/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#  27%|██▋       | 22/82 [2:31:08<9:51:47, 591.79s/it]  /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#  28%|██▊       | 23/82 [2:35:08<7:58:11, 486.30s/it]/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#  56%|█████▌    | 46/82 [3:43:19<53:04, 88.46s/it]   /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: divide by zero encountered in true_divide
#  59%|█████▊    | 48/82 [3:45:52<48:04, 84.83s/it]/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# 100%|██████████| 82/82 [8:45:24<00:00, 656.69s/it]
# ../../time-series-featurizer/ts_featurizer/base/base.py:155: UserWarning: NaN values have been found while Applying the model, check na_cols attribute to know which columns have NaNs.
# Stored the featurized files
# 8
# 1000
# /home/joanes/miniconda3/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# Loaded DataFrame lists len is 1000, from 7000 to 8000
#
#
# -------------------------------------------------- Applying the model started --------------------------------------------------
#   0%|          | 0/82 [00:00<?, ?it/s]/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: divide by zero encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: divide by zero encountered in true_divide
#   1%|          | 1/82 [1:21:07<109:30:27, 4867.01s/it]/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#  39%|███▉      | 32/82 [2:33:06<8:28:52, 610.64s/it]  /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#  45%|████▌     | 37/82 [3:43:30<7:26:31, 595.36s/it]  /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: divide by zero encountered in true_divide
# 100%|██████████| 82/82 [8:40:21<00:00, 380.75s/it]
# ../../time-series-featurizer/ts_featurizer/base/base.py:155: UserWarning: NaN values have been found while Applying the model, check na_cols attribute to know which columns have NaNs.
# Stored the featurized files
# 9
# 1000
# /home/joanes/miniconda3/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# Loaded DataFrame lists len is 1000, from 8000 to 9000
#
#
# -------------------------------------------------- Applying the model started --------------------------------------------------
#   0%|          | 0/82 [00:00<?, ?it/s]/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: divide by zero encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#   2%|▏         | 2/82 [1:20:01<74:40:55, 3360.70s/it] /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: divide by zero encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#  28%|██▊       | 23/82 [2:33:02<10:06:51, 617.14s/it] /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
# /home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
# Process ForkPoolWorker-117:
# Process ForkPoolWorker-123:
# Process ForkPoolWorker-118:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-119:
# Process ForkPoolWorker-128:
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Process ForkPoolWorker-115:
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Process ForkPoolWorker-126:
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-122:
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-120:
# Process ForkPoolWorker-113:
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
# Process ForkPoolWorker-127:
#   File "../../time-series-featurizer/ts_featurizer/base/base.py", line 279, in get_featurized_col
#     transf, prev_trans = TimeSeriesFeaturizer.featurize_each_class(column_df, featurizer)
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "../../time-series-featurizer/ts_featurizer/base/base.py", line 279, in get_featurized_col
#     transf, prev_trans = TimeSeriesFeaturizer.featurize_each_class(column_df, featurizer)
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "../../time-series-featurizer/ts_featurizer/base/base.py", line 360, in featurize_each_class
#     transf, prev_transf = featurizer.featurize(data, )
# Process ForkPoolWorker-124:
#   File "../../time-series-featurizer/ts_featurizer/tools/base.py", line 59, in featurize
#     featurized_list.append(self._apply_featurization(function=key.function_, executions=execs))
# Traceback (most recent call last):
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "../../time-series-featurizer/ts_featurizer/base/base.py", line 360, in featurize_each_class
#     transf, prev_transf = featurizer.featurize(data, )
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "../../time-series-featurizer/ts_featurizer/tools/base.py", line 120, in _apply_featurization
#     trans = self._featurize_all_columns(self._transformed_data, function, args, kwargs)
# Process ForkPoolWorker-121:
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "../../time-series-featurizer/ts_featurizer/tools/base.py", line 59, in featurize
#     featurized_list.append(self._apply_featurization(function=key.function_, executions=execs))
#   File "../../time-series-featurizer/ts_featurizer/tools/base.py", line 70, in _featurize_all_columns
#     value = func(column, *args, **kwargs)
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "../../time-series-featurizer/ts_featurizer/tools/base.py", line 120, in _apply_featurization
#     trans = self._featurize_all_columns(self._transformed_data, function, args, kwargs)
#   File "../../time-series-featurizer/ts_featurizer/base/base.py", line 279, in get_featurized_col
#     transf, prev_trans = TimeSeriesFeaturizer.featurize_each_class(column_df, featurizer)
# Traceback (most recent call last):
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "../../time-series-featurizer/ts_featurizer/tools/features.py", line 19, in series_to_ndarray
#     return func(np.asarray(x), *args, **kwargs)
#   File "../../time-series-featurizer/ts_featurizer/base/base.py", line 279, in get_featurized_col
#     transf, prev_trans = TimeSeriesFeaturizer.featurize_each_class(column_df, featurizer)
# Traceback (most recent call last):
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "../../time-series-featurizer/ts_featurizer/tools/base.py", line 70, in _featurize_all_columns
#     value = func(column, *args, **kwargs)
#   File "../../time-series-featurizer/ts_featurizer/base/base.py", line 279, in get_featurized_col
#     transf, prev_trans = TimeSeriesFeaturizer.featurize_each_class(column_df, featurizer)
# Traceback (most recent call last):
#   File "../../time-series-featurizer/ts_featurizer/tools/features.py", line 468, in augmented_dickey_fuller
#     res = adfuller(x)
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "../../time-series-featurizer/ts_featurizer/base/base.py", line 360, in featurize_each_class
#     transf, prev_transf = featurizer.featurize(data, )
# Traceback (most recent call last):
#   File "../../time-series-featurizer/ts_featurizer/tools/features.py", line 19, in series_to_ndarray
#     return func(np.asarray(x), *args, **kwargs)
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "../../time-series-featurizer/ts_featurizer/base/base.py", line 360, in featurize_each_class
#     transf, prev_transf = featurizer.featurize(data, )
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "../../time-series-featurizer/ts_featurizer/tools/base.py", line 59, in featurize
#     featurized_list.append(self._apply_featurization(function=key.function_, executions=execs))
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "../../time-series-featurizer/ts_featurizer/tools/base.py", line 59, in featurize
#     featurized_list.append(self._apply_featurization(function=key.function_, executions=execs))
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "../../time-series-featurizer/ts_featurizer/tools/base.py", line 120, in _apply_featurization
#     trans = self._featurize_all_columns(self._transformed_data, function, args, kwargs)
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tsa/stattools.py", line 241, in adfuller
#     maxlag, autolag)
#   File "../../time-series-featurizer/ts_featurizer/base/base.py", line 279, in get_featurized_col
#     transf, prev_trans = TimeSeriesFeaturizer.featurize_each_class(column_df, featurizer)
#   File "../../time-series-featurizer/ts_featurizer/base/base.py", line 360, in featurize_each_class
#     transf, prev_transf = featurizer.featurize(data, )
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "../../time-series-featurizer/ts_featurizer/tools/base.py", line 120, in _apply_featurization
#     trans = self._featurize_all_columns(self._transformed_data, function, args, kwargs)
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "../../time-series-featurizer/ts_featurizer/tools/features.py", line 468, in augmented_dickey_fuller
#     res = adfuller(x)
#   File "../../time-series-featurizer/ts_featurizer/tools/base.py", line 59, in featurize
#     featurized_list.append(self._apply_featurization(function=key.function_, executions=execs))
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tsa/stattools.py", line 87, in _autolag
#     results[lag] = mod_instance.fit()
#   File "../../time-series-featurizer/ts_featurizer/base/base.py", line 279, in get_featurized_col
#     transf, prev_trans = TimeSeriesFeaturizer.featurize_each_class(column_df, featurizer)
# Traceback (most recent call last):
#   File "../../time-series-featurizer/ts_featurizer/tools/base.py", line 70, in _featurize_all_columns
#     value = func(column, *args, **kwargs)
#   File "../../time-series-featurizer/ts_featurizer/tools/base.py", line 70, in _featurize_all_columns
#     value = func(column, *args, **kwargs)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tsa/stattools.py", line 241, in adfuller
#     maxlag, autolag)
#   File "../../time-series-featurizer/ts_featurizer/tools/base.py", line 120, in _apply_featurization
#     trans = self._featurize_all_columns(self._transformed_data, function, args, kwargs)
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "../../time-series-featurizer/ts_featurizer/tools/base.py", line 70, in _featurize_all_columns
# ...
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/numpy/linalg/linalg.py", line 1562, in svd
#     u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tsa/stattools.py", line 87, in _autolag
#     results[lag] = mod_instance.fit()
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tsa/stattools.py", line 241, in adfuller
#     maxlag, autolag)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tsa/stattools.py", line 87, in _autolag
#     results[lag] = mod_instance.fit()
#   File "../../time-series-featurizer/ts_featurizer/tools/features.py", line 468, in augmented_dickey_fuller
#     res = adfuller(x)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tsa/stattools.py", line 241, in adfuller
#     maxlag, autolag)
# KeyboardInterrupt
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py", line 273, in fit
#     self.pinv_wexog, singular_values = pinv_extended(self.wexog)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tsa/stattools.py", line 241, in adfuller
#     maxlag, autolag)
# Traceback (most recent call last):
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py", line 273, in fit
#     self.pinv_wexog, singular_values = pinv_extended(self.wexog)
# Traceback (most recent call last):
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tsa/stattools.py", line 87, in _autolag
#     results[lag] = mod_instance.fit()
#   File "../../time-series-featurizer/ts_featurizer/tools/features.py", line 19, in series_to_ndarray
#     return func(np.asarray(x), *args, **kwargs)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tsa/stattools.py", line 87, in _autolag
#     results[lag] = mod_instance.fit()
#   File "../../time-series-featurizer/ts_featurizer/tools/base.py", line 120, in _apply_featurization
#     trans = self._featurize_all_columns(self._transformed_data, function, args, kwargs)
#   File "../../time-series-featurizer/ts_featurizer/tools/features.py", line 468, in augmented_dickey_fuller
#     res = adfuller(x)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py", line 273, in fit
#     self.pinv_wexog, singular_values = pinv_extended(self.wexog)
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tsa/stattools.py", line 87, in _autolag
#     results[lag] = mod_instance.fit()
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py", line 275, in fit
#     self.pinv_wexog, np.transpose(self.pinv_wexog))
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tsa/stattools.py", line 241, in adfuller
#     maxlag, autolag)
#   File "../../time-series-featurizer/ts_featurizer/tools/base.py", line 70, in _featurize_all_columns
#     value = func(column, *args, **kwargs)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tools/tools.py", line 353, in pinv_extended
#     np.transpose(u)))
#   File "../../time-series-featurizer/ts_featurizer/base/base.py", line 279, in get_featurized_col
#     transf, prev_trans = TimeSeriesFeaturizer.featurize_each_class(column_df, featurizer)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py", line 273, in fit
#     self.pinv_wexog, singular_values = pinv_extended(self.wexog)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tools/tools.py", line 342, in pinv_extended
#     u, s, vt = np.linalg.svd(X, 0)
# KeyboardInterrupt
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tsa/stattools.py", line 241, in adfuller
#     maxlag, autolag)
#   File "../../time-series-featurizer/ts_featurizer/base/base.py", line 360, in featurize_each_class
#     transf, prev_transf = featurizer.featurize(data, )
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tools/tools.py", line 342, in pinv_extended
#     u, s, vt = np.linalg.svd(X, 0)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tsa/stattools.py", line 87, in _autolag
#     results[lag] = mod_instance.fit()
#   File "../../time-series-featurizer/ts_featurizer/tools/base.py", line 59, in featurize
#     featurized_list.append(self._apply_featurization(function=key.function_, executions=execs))
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tools/tools.py", line 342, in pinv_extended
#     u, s, vt = np.linalg.svd(X, 0)
# KeyboardInterrupt
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/numpy/linalg/linalg.py", line 1562, in svd
#     u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py", line 273, in fit
#     self.pinv_wexog, singular_values = pinv_extended(self.wexog)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tsa/stattools.py", line 87, in _autolag
#     results[lag] = mod_instance.fit()
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/numpy/linalg/linalg.py", line 1562, in svd
#     u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#   File "/home/joanes/miniconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "../../time-series-featurizer/ts_featurizer/base/base.py", line 279, in get_featurized_col
#     transf, prev_trans = TimeSeriesFeaturizer.featurize_each_class(column_df, featurizer)
# KeyboardInterrupt
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py", line 273, in fit
#     self.pinv_wexog, singular_values = pinv_extended(self.wexog)
#   File "../../time-series-featurizer/ts_featurizer/tools/base.py", line 120, in _apply_featurization
#     trans = self._featurize_all_columns(self._transformed_data, function, args, kwargs)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/numpy/linalg/linalg.py", line 1562, in svd
#     u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tools/tools.py", line 342, in pinv_extended
#     u, s, vt = np.linalg.svd(X, 0)
#   File "../../time-series-featurizer/ts_featurizer/tools/features.py", line 19, in series_to_ndarray
#     return func(np.asarray(x), *args, **kwargs)
# KeyboardInterrupt
#   File "../../time-series-featurizer/ts_featurizer/tools/base.py", line 70, in _featurize_all_columns
#     value = func(column, *args, **kwargs)
# KeyboardInterrupt
#   File "../../time-series-featurizer/ts_featurizer/base/base.py", line 279, in get_featurized_col
#     transf, prev_trans = TimeSeriesFeaturizer.featurize_each_class(column_df, featurizer)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tools/tools.py", line 353, in pinv_extended
#     np.transpose(u)))
#   File "../../time-series-featurizer/ts_featurizer/tools/features.py", line 468, in augmented_dickey_fuller
#     res = adfuller(x)
#   File "../../time-series-featurizer/ts_featurizer/base/base.py", line 360, in featurize_each_class
#     transf, prev_transf = featurizer.featurize(data, )
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/numpy/linalg/linalg.py", line 1562, in svd
#     u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#   File "../../time-series-featurizer/ts_featurizer/tools/features.py", line 19, in series_to_ndarray
#     return func(np.asarray(x), *args, **kwargs)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tsa/stattools.py", line 241, in adfuller
#     maxlag, autolag)
#   File "../../time-series-featurizer/ts_featurizer/tools/features.py", line 468, in augmented_dickey_fuller
#     res = adfuller(x)
# KeyboardInterrupt
#   File "../../time-series-featurizer/ts_featurizer/base/base.py", line 360, in featurize_each_class
#     transf, prev_transf = featurizer.featurize(data, )
#   File "../../time-series-featurizer/ts_featurizer/tools/base.py", line 59, in featurize
#     featurized_list.append(self._apply_featurization(function=key.function_, executions=execs))
# KeyboardInterrupt
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tsa/stattools.py", line 87, in _autolag
#     results[lag] = mod_instance.fit()
#   File "../../time-series-featurizer/ts_featurizer/tools/base.py", line 59, in featurize
#     featurized_list.append(self._apply_featurization(function=key.function_, executions=execs))
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tsa/stattools.py", line 241, in adfuller
#     maxlag, autolag)
#   File "../../time-series-featurizer/ts_featurizer/tools/base.py", line 120, in _apply_featurization
#     trans = self._featurize_all_columns(self._transformed_data, function, args, kwargs)
#   File "../../time-series-featurizer/ts_featurizer/tools/base.py", line 120, in _apply_featurization
#     trans = self._featurize_all_columns(self._transformed_data, function, args, kwargs)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py", line 273, in fit
#     self.pinv_wexog, singular_values = pinv_extended(self.wexog)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tsa/stattools.py", line 87, in _autolag
#     results[lag] = mod_instance.fit()
#   File "../../time-series-featurizer/ts_featurizer/tools/base.py", line 70, in _featurize_all_columns
#     value = func(column, *args, **kwargs)
#   File "../../time-series-featurizer/ts_featurizer/tools/features.py", line 19, in series_to_ndarray
#     return func(np.asarray(x), *args, **kwargs)
#   File "../../time-series-featurizer/ts_featurizer/tools/features.py", line 19, in series_to_ndarray
#     return func(np.asarray(x), *args, **kwargs)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py", line 273, in fit
#     self.pinv_wexog, singular_values = pinv_extended(self.wexog)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tools/tools.py", line 342, in pinv_extended
#     u, s, vt = np.linalg.svd(X, 0)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tools/tools.py", line 342, in pinv_extended
#     u, s, vt = np.linalg.svd(X, 0)
#   File "../../time-series-featurizer/ts_featurizer/tools/features.py", line 468, in augmented_dickey_fuller
#     res = adfuller(x)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/numpy/linalg/linalg.py", line 1562, in svd
#     u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#   File "../../time-series-featurizer/ts_featurizer/tools/features.py", line 468, in augmented_dickey_fuller
#     res = adfuller(x)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/numpy/linalg/linalg.py", line 1562, in svd
#     u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tsa/stattools.py", line 241, in adfuller
#     maxlag, autolag)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tsa/stattools.py", line 241, in adfuller
#     maxlag, autolag)
# KeyboardInterrupt
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tsa/stattools.py", line 87, in _autolag
#     results[lag] = mod_instance.fit()
# KeyboardInterrupt
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py", line 273, in fit
#     self.pinv_wexog, singular_values = pinv_extended(self.wexog)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tsa/stattools.py", line 87, in _autolag
#     results[lag] = mod_instance.fit()
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tools/tools.py", line 342, in pinv_extended
#     u, s, vt = np.linalg.svd(X, 0)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py", line 273, in fit
#     self.pinv_wexog, singular_values = pinv_extended(self.wexog)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/numpy/linalg/linalg.py", line 1562, in svd
#     u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/statsmodels/tools/tools.py", line 342, in pinv_extended
#     u, s, vt = np.linalg.svd(X, 0)
#   File "/home/joanes/miniconda3/lib/python3.6/site-packages/numpy/linalg/linalg.py", line 1562, in svd
#     u, s, vh = gufunc(a, signature=signature, extobj=extobj)
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/miniconda3/lib/python3.6/multiprocessing/pool.py in next(self, timeout)
#     719             try:
# --> 720                 item = self._items.popleft()
#     721             except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-b5b95ae0d199> in <module>
#       3     df_list, target_featurized = get_processed_df_list_and_target(raw_files, (time - 1) * 1_000, time * 1_000)
#       4     print(f'Loaded DataFrame lists len is {len(df_list)}, from {(time - 1) * 1_000} to {time * 1_000}')
# ----> 5     featurized = tseries.featurize(df_list, n_jobs=-1, apply_model=True)
#       6     featurized.reset_index(drop=True).to_feather(f'tmp/featurized_{time}')
#       7     target_featurized.reset_index(drop=True).to_feather(f'tmp/target_featurized_{time}')
#
# ~/GBL/time-series-featurizer/ts_featurizer/base/base.py in featurize(self, train, time_column, use_dask, n_jobs, apply_model)
#     135                 print(f'\n\n{"-" * 50} {application_mode} started {"-" * 50}')
#     136                 with Pool(n_jobs) as p:
# --> 137                         ret = list(tqdm(p.imap(self.get_featurized_col, kwargs), total=len(kwargs)))
#     138                 transf_column_list, prev_trans = map(list, zip(*ret))
#     139
#
# ~/miniconda3/lib/python3.6/site-packages/tqdm/_tqdm.py in __iter__(self)
#     977 """, fp_write=getattr(self.fp, 'write', sys.stderr.write))
#     978
# --> 979             for obj in iterable:
#     980                 yield obj
#     981                 # Update and possibly print the progressbar.
#
# ~/miniconda3/lib/python3.6/multiprocessing/pool.py in next(self, timeout)
#     722                 if self._index == self._length:
#     723                     raise StopIteration
# --> 724                 self._cond.wait(timeout)
#     725                 try:
#     726                     item = self._items.popleft()
#
# ~/miniconda3/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
len(raw_files)
# Out:
# 10014
