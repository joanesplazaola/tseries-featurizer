# %%
from ts_featurizer import default_conf, TimeSeriesFeaturizer

# %%
default_conf
# Out:
# {'Time': {'class': 'ts_featurizer.tools.featurizers.TimeFeaturizer',
#   'previous_trans': {},
#   'features': {'numpy.mean': [],
#    'numpy.median': [],
#    'numpy.std': [],
#    'numpy.min': [],
#    'numpy.max': [],
#    'scipy.stats.kurtosis': [],
#    'scipy.stats.sem': [],
#    'scipy.stats.skew': [],
#    'numpy.percentile': [{'args': [50]}, {'args': [95], 'kwargs': {}}],
#    'ts_featurizer.tools.signal_energy': []}},
#  'Frequency': {'class': 'ts_featurizer.tools.featurizers.FrequencyFeaturizer',
#   'previous_trans': {'ts_featurizer.tools.to_frequency': {'args': [],
#     'kwargs': {}}},
#   'features': {'ts_featurizer.tools.detect_peaks': [{'kwargs': {'show': False},
#      'test': {'preprocessors': {'ts_featurizer.tools.get_list_from_columns': {}}},
#      'model': {'preprocessor': 'ts_featurizer.tools.get_most_important_freqs',
#       'kwargs': {}}}],
#    'ts_featurizer.tools.signal_energy': [{}]}}}

# %%
new_featurizer = {'class': 'ts_featurizer.tools.base.BaseFeaturizer',
                  'previous_trans': {},
                  'features': {'numpy.var': [], 'numpy.average': []}
                 }
default_conf['TimeV2'] = new_featurizer

# %%
import pandas as pd
import numpy as np
import datetime


N = 3000

signal = np.sin(50 * np.pi * np.arange(N) / float(N / 2)) * 21

signal2 = np.sin(5 * np.pi * np.arange(N) / float(N / 2)) * 20
signal3 = np.sin(15 * np.pi * np.arange(N) / float(N / 2)) * 18 + 20
noise = np.random.normal(0, 1, N)
signal = signal + signal2 + signal3 + noise
base = datetime.datetime(2000, 1, 1)
time = np.array([base + datetime.timedelta(hours=i) for i in range(N)])

d = {
	'sensor1': signal,
	'sensor2': signal2 + noise,
	'sensor3': signal3 + noise,
	'sensor4': noise,
	'proba': list('s' * N),
	'time': time

}

data = pd.DataFrame(d)

# %%
tseries = TimeSeriesFeaturizer(config=default_conf)

transformed = tseries.featurize(data, n_jobs=16)
transformed
# Out:
# -------------------------------------------------- Training started --------------------------------------------------
# 100%|██████████| 4.00/4.00 [00:00<00:00, 73.8it/s]
#      sensor1                                                    ...                                                     sensor4
#         Time                                                    ...                                                   Frequency                                                                                             TimeV2
#   numpy.mean numpy.median  numpy.std  numpy.min  numpy.max      ...      ts_featurizer.tools.detect_peaks_5.503669112741828e-05 ts_featurizer.tools.detect_peaks_6.467274479282485e-05 ts_featurizer.tools.signal_energy numpy.var numpy.average
# 0  20.008721    20.051964  24.181032 -29.886896  70.574789      ...                                                 134.786                                                135.677                          4.648735e+06   1.03376      0.008721
#
# [1 rows x 114 columns]
